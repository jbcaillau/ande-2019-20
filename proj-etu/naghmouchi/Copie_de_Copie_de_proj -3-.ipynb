# %% [markdown]
# ![UCA](http://caillau.perso.math.cnrs.fr/logo-uca.png)
# ## L2 MIASHS - ANDE
# # Projet
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jbcaillau/ande/master?urlpath=lab/tree/proj/proj.ipynb)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jbcaillau/ande/blob/master/proj/proj.ipynb)

# %% [markdown]
# ## Exercice 1
#
#
# ### 1.1
# Une relation est dite complète si tous les éléments sont comparables : y est au moins préféré à x et x est au moins préféré à y.
#
# Si, pour au moins 2 valeurs de i dans {1, 2, 3}, on a xi < yi et ainsi (x1, x2, x3) < (y1, y2, y3) (préférences)
#
# Si on a moins de 2 valeurs de i dans {1, 2, 3} tels que xi < yi, alors (x1, x2, x3) > (y1, y2, y3) (préférences)
#
# Ainsi, tous les éléments sont comparables et la relation est bien complète.
# ### 1.2
# Une relation de préférence est transitive si, pour tous biens (x, y, z), le bien y est au moins préféré au bien x et que le bien z est au moins préféré au bien x, alors le bien z est au moins préféré au bien x.
# Notons X=(2, 3, 4) Y=(3, 4, 2) Z=(4, 2, 3). On a donc :
#
# *   X < Y (préférences)
# *   Y < Z (préférences)
# *   Z < X (préférences)
#
# Cette relation n'est donc pas transitive.

# %% [markdown]
# ## Exercice 2A
# ### 2.1
# $U(x,y)=U_0=3x^3 + x^2 y - 17x^2 - 4xy + 17x - y + 5$ donc
#
# *   $y = (-U_0 + 3x^3 - 17x^2 + 17x + 5)/(-x^2 + 4x +1)$
# *   On cherche f'(x) :
# *   $u = -U_0 + 3x^3 - 17x^2 + 17x + 5$
# *   $u' = 9x^2 - 34x + 16$
# *   $v = -x^2 + 4x + 1$
# *   $v' = -2x + 4$
# *   $u'v = (9x^2 - 34x + 16)(-x^2 + 4x + 1) = -9x^4 + 70x^3 - 143x^2 + 30x + 16$
# *   $v'u = (-2x +4)(-U_0 + 3x^3 - 17x^2 + 17x + 5) = 2U_0 x - 4U_0 - 6x^4 + 46x^3 - 102x^2 + 58x + 20$
# *   $v^2 = (-x^2 + 4x + 1)^2 = x^4 - 8x^3 + 14x^2 + 8x +1$
# *   $u'v-v'u = (-9x^4 + 70x^3 - 143x^2 + 30x + 16)-(2U_0 x - 4U_0 - 6x^4 + 46x^3 - 102x^2 + 58x + 20) = 4U_0-2U_0 x - 3x^4 + 24x^3 - 41x^2 - 28x - 4$
# *   $f'(x)=(u'v-v'u)/v^2 = (4U_0 - 2U_0x - 3x^4 + 24x^3 - 41x^2 - 28x - 4)/(-x^2 + 4x + 1)^2$
#
# Les courbes d'indifférence sont donc décroissantes. La pente de la courbe d'indifférence en tout panier de consommation est donc de signe négatif. Pour réduire la consommation d'un bien, il faut augmenter la consommation de l'autre si on veut maintenir le niveau d'utilité inchangé. Cela signifie que pour tout panier de consommation (x;y), TMS (x;y) est positif. Les préférences sont convexes si et seulement si f'(x) est croissante => f''(x) est positive.
# Programme de maximisation de l'utilité :
# $max_x,y$ $3x^3 + x^2y - 17 x^2 - 4xy + 17x -y + 5$ sous contraintes $5x + 3y < r$, x et y positifs. On sait que les préférences sont monotones. A l'optimum, on sait donc que la contrainte sera saturée. Le Lagrangien se note $L(x,y,l,m_x,m_y) = U(x,y) -> 5x + 3y - r + m_x x + m_y y$. Les conditions de Kuhn et Tucher (conditions de $1er$ ordre) dans le cas général :
#
#
# 1.   (dL(x, y, l, m)/dx) = 0 donc $U'_x(x, y) - 5l + m_x = 0$
# 2.   (dL(x, y, l, m)/dy) = 0 donc $U'_y(x, y) - 3l + m_y = 0$
# 3.   (dL(x, y, l, m)/dl) positif donc 5x = 3y </= r
# 4.   (dL(x, y, l, m)/$dm_x$ positif donc x positif
# 5.   (dL(x, y, l, m)/$dm_y$ positif donc y positif
# 6.   l positif
# 7.   $m_x$ et $m_y$ positifs
# 8.   l(5x + 3y - r) = 0
# 9.   $m_x x $ = $m_y y$ = 0
#
# Pour atteindre un niveau d'utilité positif, le consommateur peut, soit consommer des quantités positives de x et y, soit ne consommer que x, soit que y. On distingue alors 3 cas :
# 1.   Solution intérieure : x > 0 et y > 0 et $m_x = m_y = 0$. On peut simplifier les conditions de $1er$ ordre :
# Reprenons la $1ère$ condition. Cela équivaut à $9x^2 + 2xy - 34x - 4y + 17 - 5l = 0$
#
# Reprenons la $2ème$ condition. Cela équivaut à $x^2 - 4x - 1 - 3l = 0$
#
# 5x + 3y  = r, on sait que l positif et l(5x + 3y - r) = 0
#
# On remarque que les 2 premières équations donnent le principe d'égalisation marginale : $(U'_x(x,y))/P_x = (U'_y(x,y))/P_y = l$
# Le gain d'utilité par € supplémentaire dépensé doit être égal pour tous les biens. A l'optimum, le multiplicateur de Lagrange associé à la contrainte budgétaire correspond au surcroît d'utilité qui peut être détenu si le consommateur vient à disposer d'un euro supplémentaire quel que soit le bien duquel il décide d'affecter ce revenu conditionnel. Le multiplicateur correspond bien à l'utilité marginale du revenu. On obtient alors :
# $(9x^2 + 2xy - 34x - 4y + 17)/5 = (x^2 - 4x - 1) / 3$ donc $1,8x^2 + 0,4xy - 6,8x - 0,8 y + 3,4 = x^2/3 - (4x)/3 - 1/3$. Ainsi, en résolvant cette équation , on trouve y = $((-22x^2)/15 + (82x)/15 - 56/15)/(0,4x - 0,8)$
# 2.   Élément de liste
#
# ### 2.2
# Soit $U:(x,y)\mapsto U(x,y)$ une fonction d'utilité (à valeurs dans $\mathbf{R}$) dont on cherche le maximum sous les contraintes conjointes $c_1(x,y)\leq 0$, $c_2(x,y)\leq 0$ et $c_3(x,y)\leq 0$. On ne précise ni $U$ ni les $c_i$.
# On a exécuté avec Sagemath la suite d'instructions ci-dessous et obtenu la réponse qui suit. Que peut on dire des couples $(x,y)$ où $U$ est maximal ? Expliquer.
# Que peut on dire des couples $(x,y)$ où $U$ est minimal ?
#
# ```python
# var('l,m,n')
# L = (U-l*c1-m*c2-n*c3).gradient()(x,y)
# S = solve([L[0]==0,L[1]==0,l*c1==0,m*c2==0,n*c3==0],[x,y,l,m,n])
#
# print '(x,y), (l,m,n), (c1(x,y),c2(x,y),c3(x,y)) ='
# ns = 1
# for s in S:
#     x,y,l,m,n = (s[i].rhs().n(digits=2) for i in range(5))
#     print ns,(x,y),(l,m,n),(c1(x,y),c2(x,y),c3(x,y))
#     ns = ns+1
#
# (x,y), (l,m,n), (c1(x,y),c2(x,y),c3(x,y)) =
# 1 (-2.0, 0.67) (0.00, 0.00, 0.00) (2.0, -0.67, -13.)
# 2 (-1.0, 0.00) (0.00, -3.0, 0.00) (1.0, 0.00, -10.)
# 3 (0.00, 0.00) (-2.0, -6.0, 0.00) (0.00, 0.00, -5.0)
# 4 (-0.38, 2.3) (0.00, 0.00, 1.6) (0.38, -2.3, 0.00)
# 5 (0.00, 1.7) (3.0, 0.00, 2.0) (0.00, -1.7, 0.00)
# 6 (1.0, 0.00) (0.00, -6.6, 0.80) (-1.0, 0.00, 0.00)
# ```

# %% [markdown]
# ## Exercice 3B
# ### 3.1
# Un jeu est dit sous forme normale si on connaît l'ensemble des stratégies et les fonctions de gain pour chaque joueur.
#
# ### 3.2
# Une stratégie prudente est une stratégie qui assure au joueur le paiement minimum garanti.
#
# ### 3.3
# Soient $S_1$ et $S_2$ deux stratégies. On dit que $S_1$ est dominée par $S_2$ si pour tout $S_3$ : $g_1 (S_1;S_3$) < ou = $g_1(S_2;S_3)$.
#
# Si $S_1$ est dominée par toutes les autres stratégies, on dit qu'elle est dominée et on peut préciser en disant qu'elle est :
#
# *   fortement dominée si l'inégalité est stricte
# *   faiblement dominée s'il existe au moins un cas d'égalité
#
#
# ### 3.4
# Une stratégie mixte est une stratégie où le joueur sélectionne au hasard le coup qu'il joue parmi les coups possibles.
#
# ### 3.5
# Une stratégie pure fournit une définition complète de la manière dont un joueur va jouer à un jeu.
#
# ### 3.6 (BONUS)
# Reprendre les questions 3.1 à 3.5 en supposant le nouveau croupier honnête, de sorte que toutes les combinaisons de mains sont équiprobables.

# %%
import numpy as np
from scipy.optimize import linprog

# Exceptions
class StrategieInconnue(Exception):
    """Strategie Inconnue
    
    Attribut :
        s -- stratégie
    """
    def __init__(self, s):
        self.s = s

class MainInconnue(Exception):
    """Main Inconnue
    
    Attribut :
        m -- main
    """
    def __init__(self, m):
        self.m = m

class MainVide(Exception):
    """Main Vide
    """

class PbResolution(Exception):
    """Probleme de resolution du LP
    """

# Stratégies de la joueuse 1
S1m = [ 'M', 'PV', 'PP' ] # M = Mise, P = Passe, V = Voit
l1 = len(S1m)
S1 = [ (S1m[i], S1m[j], S1m[k]) for i in range(0, l1) for j in range(0, l1) for k in range(0, l1) ]
m = len(S1)

# Stratégies de la joueuse 2
S2m = [ 'VP', 'VM', 'PP', 'PM' ] # M = Mise, P = Passe, V = Voit
l2 = len(S2m)
S2 = [ (S2m[i], S2m[j], S2m[k]) for i in range(0, l2) for j in range(0, l2) for k in range(0, l2) ]
n = len(S2)

# Mains pouvant être distribuées
Mains = [ (1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2) ] # main 1 < main 2 < main 3

# Calcul des gains
def gmfun(s1, s2, main):
    """g = gmfun(s1, s2, main)
    Gain de la joueuse 1 en fonction de la main distribuée aux deux joueuses.

    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    main : main (= cartes) distribuées aux joueuses
    """
    if s1 not in S1: raise StrategieInconnue(s1)
    if s2 not in S2: raise StrategieInconnue(s2)
    if main not in Mains: raise MainInconnue(main)

    s1m = s1[main[0]-1]
    s2m = s2[main[1]-1]

    if s1m[0] is 'M': # la joueuse 1 mise

        if s2m[0] is 'V': # la joueuse 2 voit
            if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
            else: gm = -2
        elif s2m[0] is 'P': # la joueuse 2 passe
            gm = 1 # la joueuse 1 emporte le pot
        else: raise StrategieInconnue(s2)

    elif s1m[0] is 'P': # la joueuse 1 passe

        if s2m[1] is 'P': # la joueuse 2 passe
            if main[0] > main[1]: gm = 1 # la meilleure main emporte le pot
            else: gm = -1
        elif s2m[1] is 'M': # la joueuse 2 mise
            if s1m[1] is 'V': # la joueuse 1 voit
                if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
                else: gm = -2
            elif s1m[1] is 'P': # la joueuse 1 passe
                gm = -1
            else: raise StrategieInconnue(s1)
        else: raise StrategieInconnue(s2)

    else: raise StrategieInconnue(s1)

    return gm

def gfun(s1, s2):
    """g = gfun(s1, s2)
    Gain en espérance de la joueuse 1 (toutes les mains sont supposées équiprobables)
 
    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    """
    l = len(Mains)
    if l is 0: raise MainVide
    g = 0.
    for i in range(0, l):
        g = g + (1/l) * gmfun(s1, s2, Mains[i])
    return g

A = np.zeros((m, n))
for i in range(0, m):
    for j in range(0, n):
        A[i, j] = gfun(S1[i], S2[j])

d = abs(np.min(A)) + 1
A = A + d # translate les gains pour garantir une valeur > 0 du jeu mixte

# Calcul de la valeur du jeu en stratégies mixtes (minimax)
c =-np.ones(n) # min (c|x) = -max (-c|x)
b = np.ones(m) # Ax <= b 
bounds = (0, None) # 0 <= x

method='simplex'
#method='revised simplex'
#method='interior-point'

res = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method=method)
if not res.success: raise PbResolution

v = 1 / (-res.fun)
x = v * res.x
v = v - d
xx = np.round_(x, decimals=8)

print('v = ', v)
print('x = ', xx)
print('')
print("Stratégie mixte optimale de la joueuse 2 :")
for j in range(0, n):
    if xx[j] > 0:
        print(S2[j], "avec proba", xx[j])
