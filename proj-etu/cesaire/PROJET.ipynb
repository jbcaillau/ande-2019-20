# %% [markdown]
# ## Exercice 1
#
# ### Question 1:
#
# Une relation de préférence est dite complète si $\forall(x,y)\in X^2: x \preccurlyeq y$ ou $y \preccurlyeq x$
#
# Soient $(x_1,x_2,x_3)$,$(y_1,y_2,y_3) \in X$, on suppose la relation rationnelle et donc soit $x_1 \preccurlyeq y_1$ et $x_2 \preccurlyeq y_2$, soit $x_2 \preccurlyeq y_2$ et $x_3 \preccurlyeq y_3$, soit $x_1 \preccurlyeq y_1$ et $x_3 \preccurlyeq y_3$:
#
# - si $x_1 \preccurlyeq y_1$ et $x_2 \preccurlyeq y_2$, => $x_3\preccurlyeq y_3$ ou $y_3\preccurlyeq x_3$ c'est-à-dire $ x_i\preccurlyeq^* y_i$
# - si $x_2 \preccurlyeq y_2$ et $x_3 \preccurlyeq y_3$, => $x_1\preccurlyeq y_1$ ou $ y_1\preccurlyeq x_1$ c'est-à-dire $ x_i\preccurlyeq^* y_i$
# - si $x_1 \preccurlyeq y_1$ et $x_3 \preccurlyeq y_3$, => $x_2\preccurlyeq y_2$ ou $y_2 \preccurlyeq x_2$ c'est-à-dire $ x_i\preccurlyeq^* y_i$
#
# Ainsi la relation de préférence est bien complète.
#
# ### Question 2:
#
# Une relation de préférence est transitive si $\forall(x,y,z)\in X^3: x\preccurlyeq y$ et $y \preccurlyeq z$ => $x \preccurlyeq z$
#
# On prend $\bar{x}=(x_1,x_2,x_3)$,$\bar{y}=(y_1,y_2,y_3) \in X$ et on pose $\bar{z}=(z_1,z_2,z_3) \in X$ et $\preccurlyeq^*$ alors:
# $z_1 \geq^* x_1$ et $x_1 \geq^* y_1$ mais $\lnot (z_1 \geq^* y_1)$ c'est-à-dire $\lnot (z_1 \geq y_1)$
#
# Si on pose $\bar{x}=(1,2,3),\bar{y}=(2,3,1),\bar{z}=(3,1,2)$, on a bien $\bar{x}\preccurlyeq \bar{y}, \bar{y}\preccurlyeq \bar{z}$ mais on a pas pour autant $\bar{x}\preccurlyeq \bar{z}$, ainsi on peut donc dire que cette relation de préférence n'est pas transistive.
#
# ## Exercice 2
#
# ### Question 1:
#
# On a la fonction d'utilité $U(x,y)=2x^3+x^2y-9x^2-2xy+2x-4y+20$ sous les contraintes $x,y \geq 0$ et $p_1x+p_2y \le r$. On a $p_1=5, p_2=3$ et $r=5$, le problème se formule comme suit:
#
# $U(x,y)$--> max
#
# $x,y \geq 0$
#
# $5x+3y \le 5$
#
# On va d'abord montrer que les préférences sont convexes. Soit $u_0\le0$ un niveau dd'utilité fixé, on définit la courbe d'indiférence de niveau $u_0$ selon:
#
# $Cu_0=${$(x,y)\in R_+^2 |u(x,y)=u_0$}
#
#
# $(u_1\neq u_0, Cu_0\cap Cu_1\neq \varnothing)$
#
# $(x,y)\in Cu_0$ <=> $u(x,y)=u_0$
#
# <=> $2x^3+x^2y-9x^2-2xy+2x-4y+20$
#
# Ecrivons x en fonction de y:
#
# <=> $(-4-2x+x^2)y=u_0-2x^3+9x^2-2x-20$
#
# <=> $y=\frac{u_0-2x^3+9x^2-2x-20}{-4-2x+x^2}=f(x)$
#
# car $x\le 0,x^2-2x>0,x^2 -2x-4\neq0$
#
# $y= \frac{u_0-2x^3+9x^2-2x-20}{-4-2x+x^2}=f(x)$ on a C$u_0$ représenté comme le graphe de f
#
# On dit que les préférences qui sont modélisés par l'utilité sont monotones.
#
# $f'(x)= \frac {-u_0} {(x^2-2x-4)^2} + \frac {-2x^4+6x^3+10x^2-114x+48} {(-4-2x+x^2)^2}$
#
# $f''(x)= (\frac {u_0} {(x^2-2x-4)^3} + \frac {-2x^3+9x^2+2x-20}{(x^2-2x-4)})\geq0$ donc les préférences sont convexes.
#
# Par défintion, le Lagrangien du problème est:
# $L(x,y,µ_1,µ_2,µ_3)=c(x,y)+µ_1g_1(x,y)+µ_2g2(x,y)+µ_3g_3(x,y)=c(z)+(u,g(z))$
# $µ=(µ_1,µ_2,µ_3)\in R^3 et z=(x,y)$
#
# Si $\bar{z}=(\bar{x},\bar{y})$ est solution du problème il existe $\bar{µ}=(\bar{µ_1},\bar{µ_2},\bar{µ_3})$ telle que:
# - $\nabla_z(\bar{z},\bar{µ})=0$
# - $\bar{µ}\geq 0$
# - $\bar{µ_i}g_i(\bar{x},\bar{y})=0$ soit $\bar{g_i}=0$ car $\bar{µ_i}\geq 0$
#
#
#
#
# $U(x,y)=2x^3+x^2y-9x^2-2xy+2x-4y+20$
#
# $α=2x^3+x^2y-9x^2-2xy+2x-4y+20+λ(5-5x+3y)$
#
# $= 2x^3+x^2y-9x^2-2xy+2x-4y+20+5λ-5xλ+3yλ$
#
#
# $\frac {\partial L} {\partial x}=0,\frac {\partial L} {\partial y}=0,\frac {\partial L} {\partial λ}=0 $
#
# -------
#
# (1) $6x^2+2xy-18x-2y+2-5λ=0$
#
# (2) $x^2-2x-4+3λ=0$
#
# (3) $-5x+3y+5=0$
#
# --------
# (1) $6x^2+2xy-18x-2y+2=5λ$
#
# (2) $x^2-2x-4=-3λ$
#
# (3) $5x-3y=5$
#
# --------
#
# $\frac {(1)} {(2)}: \frac {6x^2+2xy-18x-2y+2}{x^2-2x-4}=\frac {5λ}{-3λ}=\frac {5}{-3}$
#
# $(3): 5x-3y=5$
#
# -------
#
# $\frac {6x^2+2xy-18x-2y+2}{x^2-2x-4}=\frac {5}{-3}$
#
# $x=1+\frac {3y}{5} $
#
# ------
# https://imagizer.imageshack.com/img924/967/YrqfXz.png
#
#
#
# Pour $r=5$ on est ramené à maximiser l'utilité sur le segment qui relie $(0,\frac{5}{3})$ à $(0,1)$ sur ce segment on peut exprimé y en fonction de x:
#
# $y=\frac{5}{3}-\frac{5}{3}x$ on doit donc maximiser $φ(x)=u(x,\frac{1}{3}(5-5x))$ avec $x\in[0,1]$
#
#
# ##Exercice 3
#
# ###Question 1
#
# Ici on les mains de $J_1$ et $J_2$ telle que $M=($main de $J_1$, main de $J_2)={(1,2),(1,3),(2,1)(2,3),(3,1),(3,2)}$ mais la probabilité que $M=(2,3)$ est égale à 1/4 et toute les autres sont égales à 3/20

# %%
def gmfun(s1, s2, main):
    """g = gmfun(s1, s2, main)
    Gain de la joueuse 1 en fonction de la main distribuée aux deux joueuses.

    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    main : main (= cartes) distribuées aux joueuses
    """
    if s1 not in S1: raise StrategieInconnue(s1)
    if s2 not in S2: raise StrategieInconnue(s2)
    if main not in Mains: raise MainInconnue(main)

    s1m = s1[main[0]-1]
    s2m = s2[main[1]-1]

    if s1m[0] is 'M': # la joueuse 1 mise

        if s2m[0] is 'V': # la joueuse 2 voit
            if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
            else: gm = -2
        elif s2m[0] is 'P': # la joueuse 2 passe
            gm = 1 # la joueuse 1 emporte le pot
        else: raise StrategieInconnue(s2)

    elif s1m[0] is 'P': # la joueuse 1 passe

        if s2m[1] is 'P': # la joueuse 2 passe
            if main[0] > main[1]: gm = 1 # la meilleure main emporte le pot
            else: gm = -1
        elif s2m[1] is 'M': # la joueuse 2 mise
            if s1m[1] is 'V': # la joueuse 1 voit
                if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
                else: gm = -2
            elif s1m[1] is 'P': # la joueuse 1 passe
                gm = -1
            else: raise StrategieInconnue(s1)
        else: raise StrategieInconnue(s2)

    else: raise StrategieInconnue(s1)

    return gm

def gfun(s1, s2):
    """g = gfun(s1, s2)
    Gain en espérance de la joueuse 1 (toutes les mains sont supposées équiprobables)
 
    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    """
    l = len(Mains)
    if l is 0: raise MainVide
    g = 0.
    for i in range(0, l):
        g = g + (1/l) * gmfun(s1, s2, Mains[i])
    return g

A = np.zeros((m, n))
for i in range(0, m):
    for j in range(0, n):
        A[i, j] = gfun(S1[i], S2[j])

d = abs(np.min(A)) + 1
A = A + d # translate les gains pour garantir une valeur > 0 du jeu mixte

# %% [markdown]
# ### Question 2
#
# Un profil de stratégies prudentes n'est pas toujours un équilibre de Nash, mais peut-être une manière de jouer raisonnable pour des joueurs averses au risque ou qui n'ont pas confiance en la rationalité de l'autre joueur.
#
# ### Question3
#
# Soient $s_1$ et $s'_1$ deux stratégies du joueur 1, on dit que $s_1$ est dominée par $s'_1$ si:
# $\forall s_2 \in S_2: g_1(s_1,s_2) \le g_1(s'_1,s_2)$
#
#
# ### Question 4
