# %% [markdown]
# ![UCA](http://caillau.perso.math.cnrs.fr/logo-uca.png)
# ## L2 MIASHS - ANDE
# # Projet
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jbcaillau/ande/master?urlpath=lab/tree/proj/proj.ipynb)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jbcaillau/ande/blob/master/proj/proj.ipynb)

# %% [markdown]
# ## Exercice 1
# On se place sur $X = {\mathbf{R}}^3_+$ et on considère la relation de préférence notée $\preccurlyeq$ définie comme suit :
# $(x_1,x_2,x_3) \preccurlyeq (y_1,y_2,y_3)$ si et seulement pour au moins deux valeurs de $i$ dans $\{1, 2, 3\}$ on a $x_i \leq y_i$.
#
# ### 1.1
# Montrer cette relation de préférence est complète.
#
# ### 1.2
# À l'aide d'un contrexemple, montrer que cette relation de préférence n'est pas transitive.

# %% [markdown]
# ## Exercice 2A
# ### 2.1
# Discuter du maximum de la fonction d'utilité $U(x,y)=3x^3 + x^2 y - 17x^2 - 4xy + 17x - y + 5$ sous les contraintes $x\geq 0$, $y\geq 0$ et la contrainte de revenu $5x+3y\leq r$ pour $r=20$ puis pour $r=5$.
# Vérifier avec un dessin du graphe de $U$.
#
# ### 2.2
# Soit $U:(x,y)\mapsto U(x,y)$ une fonction d'utilité (à valeurs dans $\mathbf{R}$) dont on cherche le maximum sous les contraintes conjointes $c_1(x,y)\leq 0$, $c_2(x,y)\leq 0$ et $c_3(x,y)\leq 0$. On ne précise ni $U$ ni les $c_i$.
# On a exécuté avec Sagemath la suite d'instructions ci-dessous et obtenu la réponse qui suit. Que peut on dire des couples $(x,y)$ où $U$ est maximal ? Expliquer.
# Que peut on dire des couples $(x,y)$ où $U$ est minimal ?
#
# ```python
# var('l,m,n')
# L = (U-l*c1-m*c2-n*c3).gradient()(x,y)
# S = solve([L[0]==0,L[1]==0,l*c1==0,m*c2==0,n*c3==0],[x,y,l,m,n])
#
# print '(x,y), (l,m,n), (c1(x,y),c2(x,y),c3(x,y)) ='
# ns = 1
# for s in S:
#     x,y,l,m,n = (s[i].rhs().n(digits=2) for i in range(5))
#     print ns,(x,y),(l,m,n),(c1(x,y),c2(x,y),c3(x,y))
#     ns = ns+1
#
# (x,y), (l,m,n), (c1(x,y),c2(x,y),c3(x,y)) =
# 1 (-2.0, 0.67) (0.00, 0.00, 0.00) (2.0, -0.67, -13.)
# 2 (-1.0, 0.00) (0.00, -3.0, 0.00) (1.0, 0.00, -10.)
# 3 (0.00, 0.00) (-2.0, -6.0, 0.00) (0.00, 0.00, -5.0)
# 4 (-0.38, 2.3) (0.00, 0.00, 1.6) (0.38, -2.3, 0.00)
# 5 (0.00, 1.7) (3.0, 0.00, 2.0) (0.00, -1.7, 0.00)
# 6 (1.0, 0.00) (0.00, -6.6, 0.80) (-1.0, 0.00, 0.00)
# ```

# %% [markdown]
# ## Exercice 3A
# On considère le jeu de poker simplifié à deux joueurs suivant. Trois mains sont possibles, numérotées de $1$ à $3$, de la plus faible à la plus forte. Chaque joueuse, ayant reçu l'une de ces mains, met un jeton au pot. Le jeu se déroule ensuite selon le schéma ci-dessous (jeu séquentiel), sachant que, pour _miser_ ou pour _voir_, une joueuse doit rajouter un jeton au pot (rien à mettre au pot si la joueuse choisit de _passer_). La gagnante remporte le pot.
# La joueuse 2 triche et, à l'insu de la joueuse 1, s'est arrangée avec le croupier qui distribue les cartes afin que la main $(2, 3)$ (qui lui est favorable) sorte plus souvent que les autres, avec une probabilité de $1/4$ (les cinq autres mains sortant avec une même probabilité de $3/20$).
#
# ![Règles du jeu](https://github.com/jbcaillau/ande/blob/master/proj/poker.png?raw=1)
#
# ### 3.1
# Calculer la matrice des gains (en espérance) du jeu sous forme normale.
#
#
# ### 3.2
# Déterminer les stratégies _prudentes_ de chaque joueuse, c'est à dire la stratégie $\max_i \min_j$ pour la joueuse 1 et $\min_j \max_i$ de la joueuse 2. Y a-t-il équilibre (en stratégies pures) ?
#
# ### 3.3
# Déterminer les éventuelles stratégies dominées de chaque joueuse.
#
# ### 3.4
# Déterminer la valeur du jeu en stratégies mixtes, et donner un couple de stratégies mixtes en équilibre.
#
# ### 3.5
# Un nouveau croupier remplace le précédent. Quatre mains sont désormais possibles, numérotées de $1$ à $4$, de la plus faible à la plus forte. Donner l'ensemble des stratégies (pures) pour chaque joueuse dans le jeu sous forme normale.
#
# ### 3.6 (BONUS)
# Reprendre les questions 3.1 à 3.5 en supposant le nouveau croupier honnête, de sorte que toutes les combinaisons de mains sont équiprobables.
#
# ###1.1
#
# $X=R_+^3$ ;
#
#  $\preccurlyeq$ : ($X_1$,$X_2$,$X_3$) $\preccurlyeq$ ($Y_1$,$Y_2$,$Y_3$)
#
# ssi $X_i$ $\preccurlyeq$ $Y_i$ pour au moins deux valeurs de $i$
#
# 1) Montrons que $\preccurlyeq$ est complète,
# c'est-à-dire que tous les eéléments de $X$ sont comparables.
#
# $X= R_+^3$ ;
#
# $\forall$ $X$ =($X_1$,$X_2$,$X_3$) $\in$ $R_+^3$ ;
#                 $\forall$ $Y$ =($Y_1$,$Y_2$,$Y_3$)  $\in$  $R_+^3$ :
#
#
#
#
#
# $\forall$ $X,Y$ $\in$ $R_+^3$ :
#
# * si \{$Y_1$ $\geqslant$  $X_1$
#      \{$Y_2$ $\geqslant$  $X_2$
#
#     \{$Y_3$ $\geqslant$  $X_3$
#
#
# alors $X$ $\preccurlyeq$ $Y$
#
# * si \{$Y_1$ $\geqslant$ $X_1$
#
#      \{$Y_2$$\geqslant$ $X_2$
#
#      \{$Y_3$ $\le$ $X_3$
#
#
#  alors $X$ $\preccurlyeq$ $Y$
#
# * si \{$Y_1$ $\geqslant$  $X_1$
#      \{$Y_2$ $\le$ $X_2$
#
#      \{$Y_3$  $\geqslant$  $X_3$
#
#
# alors $X$ $\preccurlyeq$ $Y$
#
# * si \{$Y_1$$\le$ $X_1$
#      \{$Y_2$$\geqslant$ $X_2$
#
#      \{$Y_3$  $\geqslant$  $X_3$
#
# alors  $X$ $\preccurlyeq$ $Y$.
#
# Dans tous les autres cas, $Y$ $\preccurlyeq$ $X$
# donc, $\forall$ $X,Y$  $\in$ $R_+^3$, $X$  et $Y$ sont comparables.
# Donc,  $\preccurlyeq$ est complète.
#
# ###3.2
#
# $\preccurlyeq$ est transitive ssi $\forall$ ( $X$ ,$Y$,$Z$) $\in$ ($R_+^3$) :
#
# Si  $X$ $\preccurlyeq$$Y$ et  $Y$$\preccurlyeq$$Z$ alors $X$ $\preccurlyeq$$Z$.
#
#
# Donc $\preccurlyeq$ n'est pas transitive si il $\exists$ ($X$,$Y$,$Z$) $\in$ ($R_+^3$)
#
# tel que $X$  $\preccurlyeq$ $Y$ ,$Y$ $\preccurlyeq$ $Z$ et $Z$ $\preccurlyeq$ $X$
#
#
# Prenons un exemple :
#
# On note le panier $A$($2$,$3$,$4$) , $B$($2$,$3$,$1$) et  $C$($1$,$3$,$1$).
#
# On a $A$($2$,$3$,$4$) $\preccurlyeq$ $B$($2$,$3$,$1$) et $B$($2$,$3$,$1$) $\preccurlyeq$ $C$($1$,$3$,$1$) .
#
# Or, $A$ $\npreceq$ $C$ car ces deux paniers ne vérifient pas les conditions de $\preccurlyeq$.
#
# ###2.1
# On peut factoriser $U(x,y)$: $U(x,y)=(x^2-4x-1)*(3x+y-5)$
# soit $U_0$>=$0$
# $U(x,y)=U_0$
# $Y$=$U_0$/$(x^2-4x-1)$$-3x+5$
# $f(x)=U_0 / (x^2-4x-1) -3x+5$
# On remarque l'utilité est croissante en $X$ et en $Y$ les préférences de l'argent sont alors monotone. À l'optimum on sait que la contrainte budgétaire sera saturé.
#
#
# Les conditions de Kuhn tucker
#
# Pour atteindre un niveau d'utilité strictement positif le consommateur soit consommé des quantités positifs de $X$ et $Y$ soit maximiser sa consommation de $X$ sans consommer d'$Y$ sont maximiser sa consommation d'$Y$ sans consommer de $X$
#
# Solution intérieur :
#
# À l'optimum le multiplicateur Lagrange $\mu$ correspond au surcoit d'utilité qui peut être obtenue c'est le consommateur via à déposer un dollar supplémentaire c'est le cas ici utilité et les prix sont proportionnel
#
# $$\partial$$L$ /$\partial$$x=0 $\Leftrightarrow$ $U'x(x,y)-5$\mu$*=0.$    1
# $\partial$$L$/$\partial$$Y$=0  \Leftrightarrow$ $U'y(x,y)-3$\mu$ etoile=0.$   2
# $5x etoile +3y etoile =R$
# $\mu$ etoile superieurs ou egale zero
# $\mu$ etoile ( 5xetoile +3y etoile -r)=0
# de 1 et de 2 on a U'x(x,y)=5 $\mu$et pile et U'y(x,y)=3$\mu$
#
#
#
#
# on a systeme : $9x^2 +2xy -34x-4y +17=5\mu$
#                $x^2-4x-1=3$\mu$
#
#                $(9x^2+2xy-34x-4y+17)/(x^2-4x-1)=5/3$
#
#
#                ce qui donne $y(2x-4)=-22x^2/3 -85x/3-56/3$
#
#                la contrante budgetaire est saturee donc on peut ecrire $y$ en fonction de $x$ $y=r/3$ $-5/3x
#                ce qui nous donne 12x^2+145x=24
#                on a 5x+3Y inferieur ou egale a 20
#                le max que x peut prendre est 4 ( en annulant y)
#                donc x appartient a l'intervale 0,4 ferme
#                on deduit alors que x ne peut etre solution de ce systeme donc la fonction d'utilite n'admet pas de max a l'interieur
#
# Solution  au coin n1
# Contrainte budgétaire est saturé donc yetoile=0 et xetoile=4
#                on a $\partial$$L$/$\partial$$X$=0
#                equivaut a 9x^2etoile-34xetoile+15-5$\mu$etoile=0
#                     $\partial$$L$/$\partial$$Y$=0
#                     equivaut a 2xetoile -4xetoile-1-3$\mu$etoile+mu2=0
#                     5xetoile +3yetoile=r
#                     $\mu$ etoile superiuer ou egale a 0
#                     mu1=0 et Mu2 superieur ou egale 0
#                    $\mu$ etoile(5XETOILE +3yetoile-20)=0
#
#                     de l'equation 1 on a que 2x -4x -1 -27/5x^2 +102x/5-51/5=-mu1
#                     et mu1 est positive allors notre equation est negative
#  2x -4x -1 -27/5x^2 +102x/5-51/5 inferieur ou egale zero
#  pour x appartenant a 0,4 ferme ceci est possible DONC LA FONCTION D'UTILITE ADMET UN MAXIMIM EN CE COIN
#
# Au coin n2 on a alors xetoile=0 et yetoile=20/3
#
#  on a aussi $\partial$$L$/$\partial$$X$=0 equivaut a -4y-1-5$\mu$*+mu1=0
#  $\partial$$L$/$\partial$$Y$=0 equivaut a -1-3$\mu$etoile=0
#  5x*+3y*=r
#  $\mu$etoile superieur ou egale a 0
#  on peut s'aretter ici sans developper et aller plus loin car ce systeme represente une contradition car de l'equation 2 on trouve que $\mu$ est negative mais on a comme condition $\mu$ positive
#  donc U n'admet pas de solution en ce coin
#  pour conclure U admet un maximum au coin de qaund yetoile=0 et xetoile=4
# ###2.2
#
# ###3.1
#
#   Soit $S_1$ l'ensemble des stratégies de $J_1$.
#
# Connaissant sa propre main, $J_1$ peut choisir :
#
#   -Soit de miser en l'état $0$ ($M_0$) ;
#
#   -Soit de passer en l'état $0$ puis de voir en l'état $3$ ($P_0V_3$) ;
#
#   -Soit de passer en l'état $0$ puis de passer en l'état $3$ ($P_0P_3$) ;
#
# Donc : $S_1 = \{(M_0), (P_0V_3), (P_0P_3)\}$ et $Card(S_1)=3.$
#
#   Soit $S_2$ l'ensemble des stratégies de $J_2$.
#
# Connaissant sa propre main, $J_2$ peut choisir :
#
#   -En l'état $1$, soit de voir, soit de passer $(V_1 ou P_1)$ ;
#
#   -En l'état $2$, soit de miser, soit de passer $(M_2 ou P_2)$;
#
# Donc : $S2 = \{(V_1P_2), (V_1M_2), (P_1P_2), (P_1M_2)$\} et $Card(S_2)=4$.
#
#   L'ensemble des situations de jeu possibles est l'ensemble $S_1$x$S_2$ :
#
# $S1$x$S2$ = $\{(M_0 , V_1P_2) , (M_0 , V_1M_2) , (M_0 , P_1P_2) , (M_0 , P_1M_2),           (P_0V_3 , V_1P_2) , (P_0V_3 , V_1M_2) , (P_0V_3 , P_1P_2) , (P_0V_3 , P_1M_2),            (P_0P_3 , V_1P_2) , (P_0P_3 , V_1M_2) , (P_0P_3 , P_1P_2) , (P_0P_3 , P_1M_2) \}$
#
# et $Card(S_1xS_2)=Card(S_1)*Card(S_2) = 12 $.
#
#   Soit $Mains$ l'ensemble des mains de $J_1$ et $J_2$ possibles :
#
# $Mains = \{1,2,3\}x\{1,2,3\}/\{(1,1),(2,2),(3,3)\}$.
#
# Soit $A$ l'ensemble des mains de $M$ telles que $J_1$ a la meilleure main.
#
# $A=\{(2,1),(3,1),(3,2)\}$
#
# $M/A$ est l'ensemble des mains de $Mains$ telles que $J_2$ a la meilleure main.
#
# $M/A= \{(1,2),(1,3),(2,3)\}$
#
# Considérons la main $M$ de $J_1$ et $J_2$ comme une variable aléatoire discrète à valeurs dans l'ensemble $Mains$.
#
# $P(M \in A ) = P(M=(2,1)) + P(M=(3,1)) + P(M=(3,2)) = \frac{3}{20} +\frac{3}{20} + \frac{3}{20} = \frac{9}{20}$
#
# $P(M \notin A ) = P(M=(1,2)) + P(M=(1,3)) + P(M=(2,3)) = \frac{3}{20} + \frac{3}{20} + \frac{1}{4} = \frac{11}{20}$
#
# Calcul de la fonction de gain du jeu $g(s_1,s_2)$ :
#
# Comme le jeu est à sommes nulles, la Joueuse $1$ gagne ce que la Joueuse $2$ perd :
# $g_1(s_1, s_2) = -g_2(s_1, s_2)$
#
# On calcule donc uniquement la fonction de gain de la joueuse $1$ : $g(s_1,s_2) = g_1(s_1, s_2)$
#
# Dans les situations de jeu où $J_1$ gagne quelle que soit sa main, c'est-à-dire $(M_0,P_1P_2)$ et $(M_0, P_1M_2)$:
#
# $g_1(M_0, P_1P_2) = g_1(M_0, P_1M_2) = 1$
#
# Dans les situations de jeu où $J_2$ gagne quelle que soit sa main, c'est-à-dire $(P_0P_3,V_1M_2)$ et $(P_0P_3, P_1M_2)$ :
#
# $g_1(P_0P_3,V_1M_2) = g_1(P_0P_3, P_1M_2) = -1 $
#
# Dans les situations où la joueuse qui a la meilleure main gagne : $M$ étant considérée comme une variable aléatoire discrète, on a :
#
# $g_1(s_1,s_2) = E(g_1(s_1,s_2,M) = \sum_{m\in M} g_1(s_1,s_2,m)*P(M=m)$
#
# $g_1(s_1, s_2) = \sum_{m\in A} g_1(s_1, s_2, m) * P(m in A) + \sum_{m\notin A} g_1(s1,s_2, m) * P(m \notin A)$
#
# Pour les situations $(M_0,V_1P_2)$ et $(M_0,V_1M_2)$ :
#
# Si $M\inA$ :
# $g_1(M_0,V_1P_2) = g_1(M_0,V_1M_2) = 2$
#
# Sinon :
# $g_1(M_0,V_1P_2) = g_1(M_0,V_1M_2) = -2$
#
# Donc $g_1(M_0,V_1P_2,m) = g_1(M_0,V_1M_2,m) = \frac{9}{20} *2 +  \frac{11}{20} * (-2) = \frac{-1}{10}$
#
# Pour les situations $(P_0V_3,V_1M_2) et (P_0V_3,P_1M_2)$ :
#
# Si $M$ $\in$ $A$:
# $g_1(P_0V_3,V_1M_2)=g_1(P_0V_3,P_1M_2)= 2$
#
# Sinon :
# $g_1(P_0V_3,V_1M_2)=g_1(P_0V_3,P_1M_2)= -2$
#
# Donc $g_1(P_0V_3,V_1M_2,m)=g_1(P_0V_3,P_1M_2,m)=  \frac{9}{20} * 2 + \frac{11}{20} * (-2) = \frac{-2}{10}$
#
# Pour les situations $(P_0V_3,V_1P_2) , (P_0V_3,P_1P_2) , (P_0P_3,V_1P_2) , (P_0P_3,P_1P_2)$ :
# g_1(P_0V_3,V_1P_2) = g_1(P_0V_3,P_1P_2) = g_1(P_0P_3,V_1P_2) = g_1(P_0P_3,P_1P_2) = 1$
#
# Sinon :
# $g_1(P_0V_3,V_1P_2) = g_1(P_0V_3,P_1P_2) = g_1(P_0P_3,V_1P_2) = g_1(P_0P_3,P_1P_2) = -1$
#
# Donc
# $g_1(P_0V_3,V_1P_2,m) = g_1(P_0V_3,P_1P_2,m) = g_1(P_0P_3,V_1P_2,m) = g_1(P_0P_3,P_1P_2,m) =  \frac{9}{20}*1+\frac{11}{20} * (-1) = \frac{1}{10}$
#
# Matrice des gains (en espérance) du jeu sous forme normale :
#
# $$A= $$
# \begin{matrix}
# \frac{-1}{10} & \frac{-1}{10} & 1 & 1 \\
# \frac{-1}{10} & \frac{-2}{10} & \frac{-1}{10} & \frac{-2}{10} \\
# \frac{-1}{10} & -1 & \frac{-1}{10} & -1 \\
# \end{matrix}
# $$
#
#
# ### 3.2
# Trouver des stratégies prudentes pour $J_1$ correspond à trouver les stratégies $s_1 \in S_1$ telles que $J_1$ maximise son pire gain.
#
#
# $min_{j={1,2,3,4}}(a_{1j})=-1/10$
#
# $min_{j={1,2,3,4}}(a_{2j})=-2/10$
#
# $min_{j={1,2,3,4}}(a_{3j})=-1$
#
# Donc :
#
# $max_{i={1,2,3}}min_{j={1,2,3,4}}(a_{ij})=min_{j={1,2,3,4}}(a_{1j})=-1/10$
#
# Donc, la stratégie prudente de $J_1$ est la stratégie opérée à la ligne $1$, c'est-à-dire la stratégie $M_0$.
#
# Trouver des stratégies prudentes pour $J_2$ correspond à trouver les stratégies $s_2 \in S_2$ telles que $J_2$ minimise sa plus grande perte.
#
# $max_{i={1,2,3}}(a_{i1})=-1/10$
#
# $max_{i={1,2,3}}(a_{i2})=-1/10$
#
# $max_{i={1,2,3}}(a_{i3})=1$
#
# $max_{i={1,2,3}}(a_{i4})=1$
#
# Donc :
#
# $min_{j={1,2,3,4}}max_{i={1,2,3}}(a_{ij})=max_{i={1,2,3}}(a_{i1})=max_{i={1,2,3}}(a_{i2})=-1/10$
#
#
# Donc,les stratégies prudentes de $J_2$ sont les stratégies opérées aux colonnes $1$ et $2$, c'est-à-dire les stratégies $(V_1P_2)$ et $(V_1M_2)$.
#
# Les situations dans lesquelles $J_1$ et $J_2$ jouent chacune leurs stratégies prudentes sont les situations $(M_0,V_1P_2)$ et $(M_0,V_1M_2)$.
#
# Les situations $(M_0,V_1P_2)$ et $(M_0,V_1M_2)$ sont des équilibres de Nash si :
#
# PRTTs1 in $S_1$ : $g_1(s_1,V_1P_2) $\leqslant$ g_1(M_0,V_1P_2)$
#
# PRTTs2 in $S_2$ : $-g_1(M_0,s_2) $\leqslant$ -g_1(M_0,V_1P_2)$
# $\iff$ $g_1(M_0,s_2) $\geqslant$ g_1(M_0,V_1P_2)$
#
# PRTT $s_1$ in $S_1$, $g_1(s_1,V_1P_2)=-1/10=g_1(M_0,V_1P_2)$
#
# Pour $s_2=V_1M_2$ , $g_1(M_0,V_1M_2)=-1/10= _1(M_0,V1_P_2)$
#
# Pour $s_2=P_1P_2$ ou $s_2=P_1M_2$, $g_1(M_0,P_1P_2)=g_1(M_0,P_1M_2)=1 \gt g_1(M_0,V_1P_2)$
#
# Donc les situations $(M_0,V_1P_2)$ et $(M_0,V_1M_2)$ sont des situations d'équilibre.
#
#
#
# $g_2(s_1 , \overline{s_2})$ plus petit ou égal à $g_2(s_1,s_2)$
#
# $\iff$ g1(s1,s2) plus petit ou égal à $g_1(s_1 , \overline{s_2})$
#
# $g_1(M_0,P_1P_2) = g_1(M_0,P_1M_2) \gt g_1(M_0,V_1M_2)=g_1(V_0,V_1P_2)$
#
# $g_1(P_0V_3,P_1P_2) = g_1(P_0V_3,V_1P_2) \gt g_1(P_0V_3,V_1M_2)=g_1(P_0V_3,P_1M_2)$
#
# $g_1(P_0P_3,P_1P_2) = g_1(P_0P_3,V_1P_2) \gt g_1(P_0P_3,V_1M_2)=g_1(P_0P_3,P_1M_2)$
#
# Donc, $P_1P_2$ est une stratégie dominée de $S_2$, et les stratégies $V_1M_2$, $V_1P_2$ et $P_1M_2$ ne sont pas dominées.
#
# ###3.3
# Pour $J_1$ :
#
# Une stratégie $\overline{s_1}$ est dite dominée si PRTT $(s_1,s_2) \in$ S_1XS_2,
#
# $g_1(\overline{s_1}, s_2)$ plus petit ou égal à $g_1(s_1,s_2)$
#
# $g_1(P_0P_3,V_1P_2)=g_1(P_0V_3,V_1P_2)=g_1(M_0,V_1P_2)$
#
# $g_1(P_0P_3,V_1M_2)\lt g_1(P_0V_3,V_1M_2)\lt g_1(M_0,V_1M_2)$
#
# $g_1(P_0P_3,P_1P_2)=g_1(P_0V_3,P_1P_2)\lt g_1(M_0,P_1P_2)$
#
# $g_1(P_0P_3,P_1M_2)\lt g_1(P_0V_3,P_1M_2)\lt g_1(M_0,P_1M_2)$
#
# Donc, $P_0P_3$ est une stratégie dominée de $S_1$, et les stratégies $P_0V_3$et $M_0$ ne sont pas dominées.
#
# Pour $J_2$ :
#
# Une stratégie $\overline{s_2}$ est dite dominée si PRTT $(s_1,s_2) \in$ $S_1$x$S_2$,
#
# $g_2(s_1 , \overline{s_2})$ plus petit ou égal à $g_2(s_1,s_2)$
#
# $\iff$ g1(s1,s2) plus petit ou égal à $g_1(s_1 , \overline{s_2})$
#
# $g_1(M_0,P_1P_2) = g_1(M_0,P_1M_2) \gt g_1(M_0,V_1M_2)=g_1(V_0,V_1P_2)$
#
# $g_1(P_0V_3,P_1P_2) = g_1(P_0V_3,V_1P_2) \gt g_1(P_0V_3,V_1M_2)=g_1(P_0V_3,P_1M_2)$
#
# $g_1(P_0P_3,P_1P_2) = g_1(P_0P_3,V_1P_2) \gt g_1(P_0P_3,V_1M_2)=g_1(P_0P_3,P_1M_2)$
#
# Donc, $P_1P_2$ est une stratégie dominée de $S_2$, et les stratégies $V_1M_2$, $V_1P_2$ et $P_1M_2$ ne sont pas dominées.

# %%
import numpy as np
from scipy.optimize import linprog

# Exceptions
class StrategieInconnue(Exception):
    """Strategie Inconnue
    
    Attribut :
        s -- stratégie
    """
    def __init__(self, s):
        self.s = s

class MainInconnue(Exception):
    """Main Inconnue
    
    Attribut :
        m -- main
    """
    def __init__(self, m):
        self.m = m

class MainVide(Exception):
    """Main Vide
    """

class PbResolution(Exception):
    """Probleme de resolution du LP
    """

# Stratégies de la joueuse 1
S1m = [ 'M', 'PV', 'PP' ] # M = Mise, P = Passe, V = Voit
l1 = len(S1m)
S1 = [ (S1m[i], S1m[j], S1m[k]) for i in range(0, l1) for j in range(0, l1) for k in range(0, l1) ]
m = len(S1)

# Stratégies de la joueuse 2
S2m = [ 'VP', 'VM', 'PP', 'PM' ] # M = Mise, P = Passe, V = Voit
l2 = len(S2m)
S2 = [ (S2m[i], S2m[j], S2m[k]) for i in range(0, l2) for j in range(0, l2) for k in range(0, l2) ]
n = len(S2)

# Mains pouvant être distribuées
Mains = [ (1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2) ] # main 1 < main 2 < main 3

# Calcul des gains
def gmfun(s1, s2, main):
    """g = gmfun(s1, s2, main)
    Gain de la joueuse 1 en fonction de la main distribuée aux deux joueuses.

    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    main : main (= cartes) distribuées aux joueuses
    """
    if s1 not in S1: raise StrategieInconnue(s1)
    if s2 not in S2: raise StrategieInconnue(s2)
    if main not in Mains: raise MainInconnue(main)

    s1m = s1[main[0]-1]
    s2m = s2[main[1]-1]

    if s1m[0] is 'M': # la joueuse 1 mise

        if s2m[0] is 'V': # la joueuse 2 voit
            if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
            else: gm = -2
        elif s2m[0] is 'P': # la joueuse 2 passe
            gm = 1 # la joueuse 1 emporte le pot
        else: raise StrategieInconnue(s2)

    elif s1m[0] is 'P': # la joueuse 1 passe

        if s2m[1] is 'P': # la joueuse 2 passe
            if main[0] > main[1]: gm = 1 # la meilleure main emporte le pot
            else: gm = -1
        elif s2m[1] is 'M': # la joueuse 2 mise
            if s1m[1] is 'V': # la joueuse 1 voit
                if main[0] > main[1]: gm = 2 # la meilleure main emporte le pot
                else: gm = -2
            elif s1m[1] is 'P': # la joueuse 1 passe
                gm = -1
            else: raise StrategieInconnue(s1)
        else: raise StrategieInconnue(s2)

    else: raise StrategieInconnue(s1)

    return gm

def gfun(s1, s2):
    """g = gfun(s1, s2)
    Gain en espérance de la joueuse 1 (toutes les mains sont supposées équiprobables)
 
    s1 : triplet de stratégies de la joueuse 1
    s2 : triplet de stratégies de la joueuse 2
    """
    l = len(Mains)
    if l is 0: raise MainVide
    g = 0.
    for i in range(0, l):
        g = g + (1/l) * gmfun(s1, s2, Mains[i])
    return g

A = np.zeros((m, n))
for i in range(0, m):
    for j in range(0, n):
        A[i, j] = gfun(S1[i], S2[j])

d = abs(np.min(A)) + 1
A = A + d # translate les gains pour garantir une valeur > 0 du jeu mixte

# Calcul de la valeur du jeu en stratégies mixtes (minimax)
c =-np.ones(n) # min (c|x) = -max (-c|x)
b = np.ones(m) # Ax <= b 
bounds = (0, None) # 0 <= x

method='simplex'
#method='revised simplex'
#method='interior-point'

res = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method=method)
if not res.success: raise PbResolution

v = 1 / (-res.fun)
x = v * res.x
v = v - d
xx = np.round_(x, decimals=8)

print('v = ', v)
print('x = ', xx)
print('')
print("Stratégie mixte optimale de la joueuse 2 :")
for j in range(0, n):
    if xx[j] > 0:
        print(S2[j], "avec proba", xx[j])
